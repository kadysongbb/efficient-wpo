# %%
import os

import gym
import gym_electricitymarket
import gym_gridworld
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines import *
from stable_baselines.bench import Monitor
from stable_baselines.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines import results_plotter

from stable_baselines.ddpg.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

# %% [markdown]
# # TRPO

# %%
from stable_baselines.common.policies import MlpPolicy, FeedForwardPolicy

# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

# Customize value network 
class CustomPolicy(FeedForwardPolicy):
    def __init__(self, *args, **kwargs):
        super(CustomPolicy, self).__init__(*args, **kwargs,
                                           net_arch=[dict(vf=[10, 7, 5])],
                                           feature_extraction="mlp")
        
# Create and wrap the environment
env = gym.make('ElectricityMarketDiscreteDQN-v0')
env = Monitor(env, log_dir, allow_early_resets=True)
env = DummyVecEnv(([lambda: env]))

model = TRPO(MlpPolicy, env, verbose=1)

# Train the agent
time_steps = 200000
model.learn(total_timesteps=time_steps)
# Out:
# ********** Iteration 0 ************
# Optimizing Policy...
# sampling
# done in 0.468 seconds
# computegrad
# done in 0.198 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.032          0
#          1    0.00147       4.82
#          2   1.11e-06       6.55
#          3   5.51e-07       6.55
#          4   8.86e-11       6.55
# done in 0.193 seconds
# Expected: 0.141 Actual: 0.143
# Stepsize OK!
# vf
# done in 0.075 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -509         |
# | EpThisIter              | 42           |
# | EpisodesSoFar           | 42           |
# | TimeElapsed             | 1.07         |
# | TimestepsSoFar          | 1024         |
# | entloss                 | 0.0          |
# | entropy                 | 6.9021072    |
# | explained_variance_t... | -0.000219    |
# | meankl                  | 0.0056554475 |
# | optimgain               | 0.14347315   |
# | surrgain                | 0.14347315   |
# ------------------------------------------
# ********** Iteration 1 ************
# Optimizing Policy...
# sampling
# done in 0.421 seconds
# computegrad
# done in 0.068 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.035          0
#          1    0.00194       5.04
#          2    0.00145       6.09
#          3   0.000197       6.73
#          4   7.68e-06       6.83
#          5   5.76e-07       6.84
#          6   2.09e-07       6.84
#          7   7.39e-08       6.84
#          8   7.75e-09       6.84
#          9   8.15e-10       6.84
#         10   2.03e-10       6.84
# done in 0.109 seconds
# Expected: 0.148 Actual: 0.148
# Stepsize OK!
# vf
# done in 0.032 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -475         |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 85           |
# | TimeElapsed             | 1.77         |
# | TimestepsSoFar          | 2048         |
# | entloss                 | 0.0          |
# | entropy                 | 6.896222     |
# | explained_variance_t... | 0.000206     |
# | meankl                  | 0.0057536615 |
# | optimgain               | 0.14772572   |
# | surrgain                | 0.14772572   |
# ------------------------------------------
# ********** Iteration 2 ************
# Optimizing Policy...
# sampling
# done in 0.392 seconds
# computegrad
# done in 0.059 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0321          0
#          1    0.00246       4.68
#          2    0.00231       5.31
#          3   0.000579       6.21
#          4   5.96e-05       6.53
#          5   8.07e-06       6.56
#          6   8.32e-07       6.56
#          7   2.97e-07       6.56
#          8   1.23e-07       6.56
#          9   1.94e-08       6.56
#         10   4.09e-09       6.56
# done in 0.105 seconds
# Expected: 0.141 Actual: 0.141
# Stepsize OK!
# vf
# done in 0.034 seconds
# ----------------------------------------
# | EpLenMean               | 24         |
# | EpRewMean               | -481       |
# | EpThisIter              | 43         |
# | EpisodesSoFar           | 128        |
# | TimeElapsed             | 2.42       |
# | TimestepsSoFar          | 3072       |
# | entloss                 | 0.0        |
# | entropy                 | 6.8914394  |
# | explained_variance_t... | 0.000592   |
# | meankl                  | 0.00566148 |
# | optimgain               | 0.14106216 |
# | surrgain                | 0.14106216 |
# ----------------------------------------
# ********** Iteration 3 ************
# Optimizing Policy...
# sampling
# done in 0.416 seconds
# computegrad
# done in 0.057 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0356          0
#          1    0.00361       4.64
#          2    0.00234       5.03
#          3    0.00111       5.68
#          4   0.000567       6.14
#          5   5.65e-05       6.35
#          6   7.89e-06       6.38
#          7   1.24e-06       6.38
#          8   2.24e-07       6.38
#          9   6.72e-08       6.38
#         10   1.45e-08       6.38
# done in 0.103 seconds
# Expected: 0.143 Actual: 0.144
# Stepsize OK!
# vf
# done in 0.033 seconds
# ----------------------------------------
# | EpLenMean               | 24         |
# | EpRewMean               | -506       |
# | EpThisIter              | 42         |
# | EpisodesSoFar           | 170        |
# | TimeElapsed             | 3.1        |
# | TimestepsSoFar          | 4096       |
# | entloss                 | 0.0        |
# | entropy                 | 6.8841286  |
# | explained_variance_t... | 0.000821   |
# | meankl                  | 0.00617644 |
# | optimgain               | 0.1441324  |
# | surrgain                | 0.1441324  |
# ----------------------------------------
# ********** Iteration 4 ************
# Optimizing Policy...
# sampling
# done in 0.403 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0343          0
#          1    0.00428       4.34
#          2    0.00204       4.73
#          3    0.00161        5.2
#          4   0.000654       5.67
#          5   7.96e-05       5.99
#          6   1.68e-05       6.03
#          7   2.01e-06       6.03
#          8   3.38e-07       6.03
#          9    1.2e-07       6.04
#         10   3.21e-08       6.04
# done in 0.093 seconds
# Expected: 0.138 Actual: 0.135
# Stepsize OK!
# vf
# done in 0.032 seconds
# ----------------------------------------
# | EpLenMean               | 24         |
# | EpRewMean               | -422       |
# | EpThisIter              | 43         |
# | EpisodesSoFar           | 213        |
# | TimeElapsed             | 3.74       |
# | TimestepsSoFar          | 5120       |
# | entloss                 | 0.0        |
# | entropy                 | 6.880069   |
# | explained_variance_t... | 0.00114    |
# | meankl                  | 0.00580951 |
# | optimgain               | 0.13530433 |
# | surrgain                | 0.13530433 |
# ----------------------------------------
# ********** Iteration 5 ************
# Optimizing Policy...
# sampling
# done in 0.410 seconds
# computegrad
# done in 0.059 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0326          0
#          1    0.00855       4.35
#          2    0.00229       4.82
#          3    0.00164       5.53
#          4   0.000928       5.92
#          5   0.000185       6.29
#          6   2.35e-05       6.37
#          7   7.59e-06       6.38
#          8   1.44e-06       6.38
#          9   3.24e-07       6.38
#         10   1.11e-07       6.38
# done in 0.101 seconds
# Expected: 0.139 Actual: 0.139
# Stepsize OK!
# vf
# done in 0.034 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -421        |
# | EpThisIter              | 43          |
# | EpisodesSoFar           | 256         |
# | TimeElapsed             | 4.41        |
# | TimestepsSoFar          | 6144        |
# | entloss                 | 0.0         |
# | entropy                 | 6.8732615   |
# | explained_variance_t... | 0.00138     |
# | meankl                  | 0.005887362 |
# | optimgain               | 0.13938785  |
# | surrgain                | 0.13938785  |
# -----------------------------------------
# ********** Iteration 6 ************
# Optimizing Policy...
# sampling
# done in 0.388 seconds
# computegrad
# done in 0.055 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0336          0
#          1    0.00447       4.24
#          2    0.00336       4.71
#          3    0.00147       5.32
#          4   0.000759       5.91
#          5   0.000339       6.13
#          6    4.5e-05       6.23
#          7   1.49e-05       6.25
#          8   3.46e-06       6.26
#          9   6.96e-07       6.26
#         10   1.77e-07       6.26
# done in 0.094 seconds
# Expected: 0.138 Actual: 0.134
# Stepsize OK!
# vf
# done in 0.035 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -478         |
# | EpThisIter              | 42           |
# | EpisodesSoFar           | 298          |
# | TimeElapsed             | 5.05         |
# | TimestepsSoFar          | 7168         |
# | entloss                 | 0.0          |
# | entropy                 | 6.866591     |
# | explained_variance_t... | 0.00109      |
# | meankl                  | 0.0058981096 |
# | optimgain               | 0.13424024   |
# | surrgain                | 0.13424024   |
# ------------------------------------------
# ********** Iteration 7 ************
# Optimizing Policy...
# sampling
# done in 0.400 seconds
# computegrad
# done in 0.055 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0357          0
#          1    0.00528       4.37
#          2    0.00262       4.86
#          3    0.00116       5.33
#          4   0.000451       5.89
#          5   8.62e-05       6.13
#          6   3.13e-05       6.16
#          7   4.01e-06       6.18
#          8   1.05e-06       6.18
#          9   2.25e-07       6.18
#         10   8.47e-08       6.18
# done in 0.096 seconds
# Expected: 0.141 Actual: 0.138
# Stepsize OK!
# vf
# done in 0.036 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -455         |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 341          |
# | TimeElapsed             | 5.7          |
# | TimestepsSoFar          | 8192         |
# | entloss                 | 0.0          |
# | entropy                 | 6.8597946    |
# | explained_variance_t... | 0.00131      |
# | meankl                  | 0.0060108583 |
# | optimgain               | 0.13828503   |
# | surrgain                | 0.13828503   |
# ------------------------------------------
# ********** Iteration 8 ************
# Optimizing Policy...
# sampling
# done in 0.456 seconds
# computegrad
# done in 0.057 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.033          0
#          1    0.00446       4.27
#          2    0.00284       4.71
#          3    0.00124        5.2
#          4   0.000678       5.64
#          5   0.000248       5.91
#          6   6.93e-05          6
#          7   1.89e-05       6.03
#          8   3.48e-06       6.03
#          9   7.55e-07       6.04
#         10   1.79e-07       6.04
# done in 0.093 seconds
# Expected: 0.136 Actual: 0.135
# Stepsize OK!
# vf
# done in 0.035 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -430        |
# | EpThisIter              | 43          |
# | EpisodesSoFar           | 384         |
# | TimeElapsed             | 6.41        |
# | TimestepsSoFar          | 9216        |
# | entloss                 | 0.0         |
# | entropy                 | 6.853814    |
# | explained_variance_t... | 0.00127     |
# | meankl                  | 0.006028819 |
# | optimgain               | 0.13470018  |
# | surrgain                | 0.13470018  |
# -----------------------------------------
# ********** Iteration 9 ************
# Optimizing Policy...
# sampling
# done in 0.431 seconds
# computegrad
# done in 0.057 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0328          0
#          1    0.00695       4.09
#          2    0.00297       4.56
#          3    0.00158       5.13
#          4    0.00124       5.49
#          5   0.000602       5.81
#          6   0.000179       5.97
#          7   3.35e-05       6.04
#          8   8.28e-06       6.06
#          9    1.6e-06       6.06
#         10   3.27e-07       6.06
# done in 0.098 seconds
# Expected: 0.136 Actual: 0.134
# Stepsize OK!
# vf
# done in 0.036 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -435         |
# | EpThisIter              | 42           |
# | EpisodesSoFar           | 426          |
# | TimeElapsed             | 7.1          |
# | TimestepsSoFar          | 10240        |
# | entloss                 | 0.0          |
# | entropy                 | 6.8460913    |
# | explained_variance_t... | 0.00148      |
# | meankl                  | 0.0060427585 |
# | optimgain               | 0.13404776   |
# | surrgain                | 0.13404776   |
# ------------------------------------------
# ********** Iteration 10 ************
# Optimizing Policy...
# sampling
# done in 0.440 seconds
# computegrad
# done in 0.062 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0353          0
#          1     0.0101       3.86
#          2    0.00408       4.29
#          3    0.00257       4.77
#          4    0.00136       5.21
#          5   0.000565       5.68
#          6   0.000221       5.88
#          7   6.06e-05       5.95
#          8   8.44e-06       5.98
#          9   2.45e-06       5.99
#         10   6.27e-07       5.99
# done in 0.103 seconds
# Expected: 0.136 Actual: 0.137
# Stepsize OK!
# vf
# done in 0.033 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -440        |
# | EpThisIter              | 43          |
# | EpisodesSoFar           | 469         |
# | TimeElapsed             | 7.81        |
# | TimestepsSoFar          | 11264       |
# | entloss                 | 0.0         |
# | entropy                 | 6.838842    |
# | explained_variance_t... | 0.00133     |
# | meankl                  | 0.006185526 |
# | optimgain               | 0.13654509  |
# | surrgain                | 0.13654509  |
# -----------------------------------------
# ********** Iteration 11 ************
# Optimizing Policy...
# sampling
# done in 0.436 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0349          0
#          1     0.0305       3.08
#          2    0.00525        4.1
#          3    0.00271       4.55
#          4    0.00137       5.02
#          5   0.000753       5.42
#          6   0.000274        5.7
#          7   7.62e-05       5.81
#          8   2.85e-05       5.84
#          9   6.16e-06       5.85
#         10   1.44e-06       5.86
# done in 0.097 seconds
# Expected: 0.133 Actual: 0.128
# Stepsize OK!
# vf
# done in 0.029 seconds
# ----------------------------------------
# | EpLenMean               | 24         |
# | EpRewMean               | -332       |
# | EpThisIter              | 43         |
# | EpisodesSoFar           | 512        |
# | TimeElapsed             | 8.5        |
# | TimestepsSoFar          | 12288      |
# | entloss                 | 0.0        |
# | entropy                 | 6.83169    |
# | explained_variance_t... | 0.00169    |
# | meankl                  | 0.00601153 |
# | optimgain               | 0.12793687 |
# | surrgain                | 0.12793687 |
# ----------------------------------------
# ********** Iteration 12 ************
# Optimizing Policy...
# sampling
# done in 0.421 seconds
# computegrad
# done in 0.055 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.038          0
#          1     0.0134       3.79
#          2    0.00555       4.31
#          3    0.00352       4.72
#          4    0.00118       5.17
#          5   0.000842        5.6
#          6   0.000328       5.81
#          7   7.23e-05       5.95
#          8   3.46e-05       5.98
#          9   7.73e-06       5.99
#         10   3.18e-06       5.99
# done in 0.087 seconds
# Expected: 0.139 Actual: 0.135
# Stepsize OK!
# vf
# done in 0.027 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -308        |
# | EpThisIter              | 42          |
# | EpisodesSoFar           | 554         |
# | TimeElapsed             | 9.15        |
# | TimestepsSoFar          | 13312       |
# | entloss                 | 0.0         |
# | entropy                 | 6.822655    |
# | explained_variance_t... | 0.00168     |
# | meankl                  | 0.006139734 |
# | optimgain               | 0.13501309  |
# | surrgain                | 0.13501309  |
# -----------------------------------------
# ********** Iteration 13 ************
# Optimizing Policy...
# sampling
# done in 0.386 seconds
# computegrad
# done in 0.057 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.035          0
#          1     0.0491       2.81
#          2      0.008       3.92
#          3    0.00347       4.34
#          4     0.0013       4.99
#          5    0.00117       5.45
#          6   0.000419        5.7
#          7   0.000168       5.84
#          8   5.14e-05       5.89
#          9   1.11e-05       5.91
#         10   2.91e-06       5.92
# done in 0.091 seconds
# Expected: 0.133 Actual: 0.122
# Stepsize OK!
# vf
# done in 0.030 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -334        |
# | EpThisIter              | 43          |
# | EpisodesSoFar           | 597         |
# | TimeElapsed             | 9.78        |
# | TimestepsSoFar          | 14336       |
# | entloss                 | 0.0         |
# | entropy                 | 6.8175125   |
# | explained_variance_t... | 0.00206     |
# | meankl                  | 0.005731382 |
# | optimgain               | 0.12242826  |
# | surrgain                | 0.12242826  |
# -----------------------------------------
# ********** Iteration 14 ************
# Optimizing Policy...
# sampling
# done in 0.390 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0376          0
#          1     0.0486       2.82
#          2    0.00676       4.08
#          3    0.00365       4.58
#          4    0.00195       5.07
#          5    0.00105       5.41
#          6   0.000636       5.75
#          7   0.000199       5.91
#          8   6.81e-05       5.99
#          9   1.97e-05       6.01
#         10   5.44e-06       6.02
# done in 0.092 seconds
# Expected: 0.137 Actual: 0.128
# Stepsize OK!
# vf
# done in 0.027 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -340         |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 640          |
# | TimeElapsed             | 10.4         |
# | TimestepsSoFar          | 15360        |
# | entloss                 | 0.0          |
# | entropy                 | 6.8169394    |
# | explained_variance_t... | 0.00188      |
# | meankl                  | 0.0057304003 |
# | optimgain               | 0.1284191    |
# | surrgain                | 0.1284191    |
# ------------------------------------------
# ********** Iteration 15 ************
# Optimizing Policy...
# sampling
# done in 0.387 seconds
# computegrad
# done in 0.057 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0365          0
#          1     0.0728       2.23
#          2     0.0118       3.73
#          3    0.00363       4.27
#          4    0.00232       4.91
#          5    0.00137       5.31
#          6   0.000558       5.69
#          7   0.000193       5.89
#          8   4.58e-05       5.97
#          9   1.06e-05       5.99
#         10   1.37e-05          6
# done in 0.095 seconds
# Expected: 0.134 Actual: 0.128
# Stepsize OK!
# vf
# done in 0.026 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -365        |
# | EpThisIter              | 42          |
# | EpisodesSoFar           | 682         |
# | TimeElapsed             | 11          |
# | TimestepsSoFar          | 16384       |
# | entloss                 | 0.0         |
# | entropy                 | 6.8086777   |
# | explained_variance_t... | 0.00173     |
# | meankl                  | 0.005828145 |
# | optimgain               | 0.12816931  |
# | surrgain                | 0.12816931  |
# -----------------------------------------
# ********** Iteration 16 ************
# Optimizing Policy...
# sampling
# done in 0.404 seconds
# computegrad
# done in 0.057 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0381          0
#          1     0.0857       2.82
#          2    0.00567       4.05
#          3    0.00382       4.78
#          4    0.00253       5.19
#          5    0.00117       5.65
#          6    0.00045       6.01
#          7   0.000169       6.17
#          8   0.000167       6.21
#          9   6.46e-05       6.22
#         10   1.56e-05       6.24
# done in 0.089 seconds
# Expected: 0.140 Actual: 0.133
# Stepsize OK!
# vf
# done in 0.027 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -320         |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 725          |
# | TimeElapsed             | 11.7         |
# | TimestepsSoFar          | 17408        |
# | entloss                 | 0.0          |
# | entropy                 | 6.80219      |
# | explained_variance_t... | 0.00192      |
# | meankl                  | 0.0058449195 |
# | optimgain               | 0.13257752   |
# | surrgain                | 0.13257752   |
# ------------------------------------------
# ********** Iteration 17 ************
# Optimizing Policy...
# sampling
# done in 0.371 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0426          0
#          1      0.104       1.52
#          2    0.00524       4.05
#          3    0.00313       4.75
#          4    0.00185       5.11
#          5    0.00102       5.52
#          6   0.000654       5.76
#          7   0.000206       5.95
#          8   0.000346       5.98
#          9   4.27e-05       6.02
#         10   1.05e-05       6.04
# done in 0.089 seconds
# Expected: 0.139 Actual: 0.131
# Stepsize OK!
# vf
# done in 0.029 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -305        |
# | EpThisIter              | 43          |
# | EpisodesSoFar           | 768         |
# | TimeElapsed             | 12.3        |
# | TimestepsSoFar          | 18432       |
# | entloss                 | 0.0         |
# | entropy                 | 6.7938223   |
# | explained_variance_t... | 0.00197     |
# | meankl                  | 0.005947384 |
# | optimgain               | 0.13138866  |
# | surrgain                | 0.13138866  |
# -----------------------------------------
# ********** Iteration 18 ************
# Optimizing Policy...
# sampling
# done in 0.367 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0481          0
#          1     0.0878       1.11
#          2      0.012          4
#          3    0.00581       4.56
#          4    0.00244       5.27
#          5    0.00205       5.78
#          6    0.00109       6.01
#          7   0.000485       6.29
#          8   0.000341       6.39
#          9   0.000283       6.42
#         10   5.51e-05       6.46
# done in 0.089 seconds
# Expected: 0.143 Actual: 0.141
# Stepsize OK!
# vf
# done in 0.029 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -308         |
# | EpThisIter              | 42           |
# | EpisodesSoFar           | 810          |
# | TimeElapsed             | 12.9         |
# | TimestepsSoFar          | 19456        |
# | entloss                 | 0.0          |
# | entropy                 | 6.7841325    |
# | explained_variance_t... | 0.00219      |
# | meankl                  | 0.0058549326 |
# | optimgain               | 0.14105636   |
# | surrgain                | 0.14105636   |
# ------------------------------------------
# ********** Iteration 19 ************
# Optimizing Policy...
# sampling
# done in 0.377 seconds
# computegrad
# done in 0.057 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0       0.04          0
#          1     0.0472       3.12
#          2     0.0214       3.74
#          3    0.00603       4.32
#          4    0.00418       4.84
#          5    0.00223       5.23
#          6    0.00102       5.67
#          7   0.000406       6.02
#          8   0.000244       6.16
#          9   9.95e-05        6.2
#         10   0.000136       6.22
# done in 0.089 seconds
# Expected: 0.141 Actual: 0.135
# Stepsize OK!
# vf
# done in 0.027 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -283         |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 853          |
# | TimeElapsed             | 13.5         |
# | TimestepsSoFar          | 20480        |
# | entloss                 | 0.0          |
# | entropy                 | 6.7786455    |
# | explained_variance_t... | 0.00226      |
# | meankl                  | 0.0058650076 |
# | optimgain               | 0.13486126   |
# | surrgain                | 0.13486126   |
# ------------------------------------------
# ********** Iteration 20 ************
# Optimizing Policy...
# sampling
# done in 0.367 seconds
# computegrad
# done in 0.055 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0339          0
#          1     0.0822       2.79
#          2     0.0139       3.75
#          3    0.00675        4.2
#          4    0.00418       4.82
#          5    0.00238       5.19
#          6    0.00159       5.67
#          7   0.000912       5.84
#          8   0.000243        6.1
#          9    0.00023       6.19
#         10   7.81e-05       6.21
# done in 0.088 seconds
# Expected: 0.135 Actual: 0.132
# Stepsize OK!
# vf
# done in 0.027 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -318        |
# | EpThisIter              | 43          |
# | EpisodesSoFar           | 896         |
# | TimeElapsed             | 14.1        |
# | TimestepsSoFar          | 21504       |
# | entloss                 | 0.0         |
# | entropy                 | 6.7708697   |
# | explained_variance_t... | 0.00194     |
# | meankl                  | 0.005653808 |
# | optimgain               | 0.13190465  |
# | surrgain                | 0.13190465  |
# -----------------------------------------
# ********** Iteration 21 ************
# Optimizing Policy...
# sampling
# done in 0.368 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0387          0
#          1     0.0888       2.85
#          2      0.012       3.85
#          3    0.00835       4.45
#          4    0.00367       5.21
#          5    0.00308       5.52
#          6    0.00131       5.97
#          7    0.00152       6.18
#          8   0.000445       6.34
#          9   0.000143       6.47
#         10   0.000301       6.51
# done in 0.096 seconds
# Expected: 0.142 Actual: 0.135
# Stepsize OK!
# vf
# done in 0.033 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -307         |
# | EpThisIter              | 42           |
# | EpisodesSoFar           | 938          |
# | TimeElapsed             | 14.7         |
# | TimestepsSoFar          | 22528        |
# | entloss                 | 0.0          |
# | entropy                 | 6.763302     |
# | explained_variance_t... | 0.00204      |
# | meankl                  | 0.0057260934 |
# | optimgain               | 0.13544738   |
# | surrgain                | 0.13544738   |
# ------------------------------------------
# ********** Iteration 22 ************
# Optimizing Policy...
# sampling
# done in 0.413 seconds
# computegrad
# done in 0.057 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0414          0
#          1     0.0978          2
#          2     0.0173       3.66
#          3    0.00598        4.4
#          4    0.00245        5.1
#          5    0.00337       5.45
#          6    0.00136       5.74
#          7      0.001       5.97
#          8   0.000485        6.1
#          9   0.000158       6.23
#         10   0.000278       6.25
# done in 0.104 seconds
# Expected: 0.141 Actual: 0.135
# Stepsize OK!
# vf
# done in 0.027 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -284        |
# | EpThisIter              | 43          |
# | EpisodesSoFar           | 981         |
# | TimeElapsed             | 15.4        |
# | TimestepsSoFar          | 23552       |
# | entloss                 | 0.0         |
# | entropy                 | 6.7515144   |
# | explained_variance_t... | 0.00193     |
# | meankl                  | 0.006045294 |
# | optimgain               | 0.1350411   |
# | surrgain                | 0.1350411   |
# -----------------------------------------
# ********** Iteration 23 ************
# Optimizing Policy...
# sampling
# done in 0.374 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0475          0
#          1     0.0706       2.54
#          2     0.0178       3.54
#          3    0.00699       4.32
#          4    0.00507       4.87
#          5    0.00246       5.16
#          6    0.00198       5.52
#          7    0.00108       5.73
#          8   0.000417       5.95
#          9   0.000172       6.08
#         10   6.74e-05       6.14
# done in 0.086 seconds
# Expected: 0.144 Actual: 0.139
# Stepsize OK!
# vf
# done in 0.028 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -250         |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 1024         |
# | TimeElapsed             | 16           |
# | TimestepsSoFar          | 24576        |
# | entloss                 | 0.0          |
# | entropy                 | 6.74021      |
# | explained_variance_t... | 0.00186      |
# | meankl                  | 0.0062861457 |
# | optimgain               | 0.13874808   |
# | surrgain                | 0.13874808   |
# ------------------------------------------
# ********** Iteration 24 ************
# Optimizing Policy...
# sampling
# done in 0.371 seconds
# computegrad
# done in 0.055 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0418          0
#          1      0.043       2.63
#          2     0.0178       3.56
#          3     0.0089       4.14
#          4     0.0082       4.43
#          5    0.00272       4.87
#          6    0.00274       5.21
#          7   0.000935       5.53
#          8   0.000403       5.83
#          9   0.000131       5.97
#         10   3.82e-05       6.02
# done in 0.084 seconds
# Expected: 0.138 Actual: 0.129
# Stepsize OK!
# vf
# done in 0.028 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -249        |
# | EpThisIter              | 42          |
# | EpisodesSoFar           | 1066        |
# | TimeElapsed             | 16.6        |
# | TimestepsSoFar          | 25600       |
# | entloss                 | 0.0         |
# | entropy                 | 6.7312465   |
# | explained_variance_t... | 0.00187     |
# | meankl                  | 0.005904198 |
# | optimgain               | 0.12915915  |
# | surrgain                | 0.12915915  |
# -----------------------------------------
# ********** Iteration 25 ************
# Optimizing Policy...
# sampling
# done in 0.356 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0421          0
#          1     0.0552       2.42
#          2     0.0187       3.41
#          3    0.00929       4.09
#          4    0.00697        4.4
#          5    0.00269       4.86
#          6    0.00123        5.3
#          7    0.00143       5.55
#          8   0.000503        5.7
#          9   0.000195       5.86
#         10   6.87e-05       5.93
# done in 0.085 seconds
# Expected: 0.137 Actual: 0.126
# Stepsize OK!
# vf
# done in 0.029 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -185         |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 1109         |
# | TimeElapsed             | 17.2         |
# | TimestepsSoFar          | 26624        |
# | entloss                 | 0.0          |
# | entropy                 | 6.7192597    |
# | explained_variance_t... | 0.00206      |
# | meankl                  | 0.0059695547 |
# | optimgain               | 0.12632443   |
# | surrgain                | 0.12632443   |
# ------------------------------------------
# ********** Iteration 26 ************
# Optimizing Policy...
# sampling
# done in 0.373 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0422          0
#          1     0.0805       2.05
#          2     0.0188       3.37
#          3    0.00843       3.96
#          4    0.00835       4.49
#          5    0.00433       4.87
#          6    0.00325       5.17
#          7    0.00115       5.58
#          8   0.000577       5.86
#          9   0.000212       6.02
#         10   8.19e-05       6.09
# done in 0.089 seconds
# Expected: 0.137 Actual: 0.129
# Stepsize OK!
# vf
# done in 0.029 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -258         |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 1152         |
# | TimeElapsed             | 17.8         |
# | TimestepsSoFar          | 27648        |
# | entloss                 | 0.0          |
# | entropy                 | 6.7108183    |
# | explained_variance_t... | 0.00204      |
# | meankl                  | 0.0058110445 |
# | optimgain               | 0.12881653   |
# | surrgain                | 0.12881653   |
# ------------------------------------------
# ********** Iteration 27 ************
# Optimizing Policy...
# sampling
# done in 0.377 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0454          0
#          1     0.0912        1.8
#          2     0.0226        3.3
#          3     0.0121       3.86
#          4    0.00874       4.45
#          5    0.00367       4.83
#          6    0.00332       5.32
#          7    0.00167       5.57
#          8   0.000707       5.88
#          9   0.000318       6.08
#         10   0.000119       6.18
# done in 0.088 seconds
# Expected: 0.140 Actual: 0.133
# Stepsize OK!
# vf
# done in 0.027 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -242         |
# | EpThisIter              | 42           |
# | EpisodesSoFar           | 1194         |
# | TimeElapsed             | 18.4         |
# | TimestepsSoFar          | 28672        |
# | entloss                 | 0.0          |
# | entropy                 | 6.697295     |
# | explained_variance_t... | 0.00227      |
# | meankl                  | 0.0058964817 |
# | optimgain               | 0.13259079   |
# | surrgain                | 0.13259079   |
# ------------------------------------------
# ********** Iteration 28 ************
# Optimizing Policy...
# sampling
# done in 0.383 seconds
# computegrad
# done in 0.060 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0444          0
#          1     0.0861       1.78
#          2      0.032       3.14
#          3     0.0127        3.8
#          4     0.0136       4.39
#          5    0.00346       4.89
#          6    0.00329       5.44
#          7    0.00166       5.64
#          8   0.000757       5.92
#          9   0.000346       6.11
#         10    0.00013       6.22
# done in 0.086 seconds
# Expected: 0.139 Actual: 0.129
# Stepsize OK!
# vf
# done in 0.027 seconds
# ----------------------------------------
# | EpLenMean               | 24         |
# | EpRewMean               | -231       |
# | EpThisIter              | 43         |
# | EpisodesSoFar           | 1237       |
# | TimeElapsed             | 19.1       |
# | TimestepsSoFar          | 29696      |
# | entloss                 | 0.0        |
# | entropy                 | 6.6859536  |
# | explained_variance_t... | 0.00204    |
# | meankl                  | 0.00587777 |
# | optimgain               | 0.12912372 |
# | surrgain                | 0.12912372 |
# ----------------------------------------
# ********** Iteration 29 ************
# Optimizing Policy...
# sampling
# done in 0.372 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0463          0
#          1     0.0984       1.63
#          2     0.0238       3.07
#          3     0.0118       3.61
#          4    0.00928       4.13
#          5    0.00379        4.5
#          6     0.0028       4.92
#          7    0.00159       5.22
#          8   0.000733       5.53
#          9   0.000324       5.72
#         10   0.000134       5.82
# done in 0.086 seconds
# Expected: 0.136 Actual: 0.128
# Stepsize OK!
# vf
# done in 0.027 seconds
# ----------------------------------------
# | EpLenMean               | 24         |
# | EpRewMean               | -184       |
# | EpThisIter              | 43         |
# | EpisodesSoFar           | 1280       |
# | TimeElapsed             | 19.7       |
# | TimestepsSoFar          | 30720      |
# | entloss                 | 0.0        |
# | entropy                 | 6.6776757  |
# | explained_variance_t... | 0.00266    |
# | meankl                  | 0.00622336 |
# | optimgain               | 0.1283767  |
# | surrgain                | 0.1283767  |
# ----------------------------------------
# ********** Iteration 30 ************
# Optimizing Policy...
# sampling
# done in 0.370 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0492          0
#          1     0.0621       2.32
#          2      0.023       3.37
#          3     0.0153       4.05
#          4    0.00605       4.56
#          5    0.00387       4.98
#          6    0.00178       5.36
#          7   0.000948       5.65
#          8   0.000404       5.86
#          9   0.000293       5.98
#         10   0.000159       6.03
# done in 0.086 seconds
# Expected: 0.143 Actual: 0.130
# Stepsize OK!
# vf
# done in 0.027 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -217         |
# | EpThisIter              | 42           |
# | EpisodesSoFar           | 1322         |
# | TimeElapsed             | 20.3         |
# | TimestepsSoFar          | 31744        |
# | entloss                 | 0.0          |
# | entropy                 | 6.666718     |
# | explained_variance_t... | 0.00228      |
# | meankl                  | 0.0062069823 |
# | optimgain               | 0.13046074   |
# | surrgain                | 0.13046074   |
# ------------------------------------------
# ********** Iteration 31 ************
# Optimizing Policy...
# sampling
# done in 0.379 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0472          0
#          1     0.0648       2.21
#          2     0.0113       3.28
#          3    0.00769       3.94
#          4    0.00438       4.28
#          5    0.00231       4.68
#          6    0.00181       4.96
#          7     0.0009       5.25
#          8   0.000503       5.43
#          9   0.000258       5.55
#         10   0.000125       5.61
# done in 0.086 seconds
# Expected: 0.135 Actual: 0.131
# Stepsize OK!
# vf
# done in 0.036 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -224         |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 1365         |
# | TimeElapsed             | 20.9         |
# | TimestepsSoFar          | 32768        |
# | entloss                 | 0.0          |
# | entropy                 | 6.665103     |
# | explained_variance_t... | 0.00256      |
# | meankl                  | 0.0064239297 |
# | optimgain               | 0.13121675   |
# | surrgain                | 0.13121675   |
# ------------------------------------------
# ********** Iteration 32 ************
# Optimizing Policy...
# sampling
# done in 0.413 seconds
# computegrad
# done in 0.058 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0512          0
#          1     0.0744       1.51
#          2     0.0152       3.31
#          3     0.0123       3.85
#          4    0.00446       4.44
#          5    0.00322       4.83
#          6    0.00142       5.13
#          7   0.000753        5.4
#          8   0.000491       5.57
#          9   0.000202       5.67
#         10   0.000107       5.74
# done in 0.086 seconds
# Expected: 0.137 Actual: 0.126
# Stepsize OK!
# vf
# done in 0.025 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -214        |
# | EpThisIter              | 43          |
# | EpisodesSoFar           | 1408        |
# | TimeElapsed             | 21.5        |
# | TimestepsSoFar          | 33792       |
# | entloss                 | 0.0         |
# | entropy                 | 6.6550965   |
# | explained_variance_t... | 0.00207     |
# | meankl                  | 0.006249183 |
# | optimgain               | 0.12554497  |
# | surrgain                | 0.12554497  |
# -----------------------------------------
# ********** Iteration 33 ************
# Optimizing Policy...
# sampling
# done in 0.413 seconds
# computegrad
# done in 0.062 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0476          0
#          1      0.057       2.05
#          2     0.0138       3.01
#          3     0.0055       3.73
#          4    0.00357       4.14
#          5    0.00256        4.4
#          6    0.00112       4.71
#          7   0.000742       4.95
#          8   0.000345       5.12
#          9   0.000168        5.2
#         10   6.79e-05       5.25
# done in 0.115 seconds
# Expected: 0.131 Actual: 0.125
# Stepsize OK!
# vf
# done in 0.034 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -166        |
# | EpThisIter              | 42          |
# | EpisodesSoFar           | 1450        |
# | TimeElapsed             | 22.2        |
# | TimestepsSoFar          | 34816       |
# | entloss                 | 0.0         |
# | entropy                 | 6.6486773   |
# | explained_variance_t... | 0.00256     |
# | meankl                  | 0.006499182 |
# | optimgain               | 0.124827884 |
# | surrgain                | 0.124827884 |
# -----------------------------------------
# ********** Iteration 34 ************
# Optimizing Policy...
# sampling
# done in 0.429 seconds
# computegrad
# done in 0.061 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0541          0
#          1     0.0788       1.65
#          2     0.0218       3.07
#          3     0.0152        3.8
#          4    0.00643       4.39
#          5    0.00291       4.92
#          6    0.00172       5.21
#          7   0.000784       5.46
#          8   0.000458       5.64
#          9    0.00022       5.75
#         10   0.000107       5.82
# done in 0.096 seconds
# Expected: 0.140 Actual: 0.125
# Stepsize OK!
# vf
# done in 0.032 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -157         |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 1493         |
# | TimeElapsed             | 22.9         |
# | TimestepsSoFar          | 35840        |
# | entloss                 | 0.0          |
# | entropy                 | 6.634099     |
# | explained_variance_t... | 0.00222      |
# | meankl                  | 0.0062156757 |
# | optimgain               | 0.12508449   |
# | surrgain                | 0.12508449   |
# ------------------------------------------
# ********** Iteration 35 ************
# Optimizing Policy...
# sampling
# done in 0.400 seconds
# computegrad
# done in 0.063 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0453          0
#          1     0.0375       2.19
#          2     0.0149       2.87
#          3    0.00815       3.35
#          4    0.00341       3.84
#          5    0.00203       4.21
#          6    0.00111       4.51
#          7   0.000732       4.74
#          8   0.000342        4.9
#          9   0.000154       4.99
#         10   6.76e-05       5.05
# done in 0.102 seconds
# Expected: 0.126 Actual: 0.121
# Stepsize OK!
# vf
# done in 0.035 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | -96.9        |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 1536         |
# | TimeElapsed             | 23.6         |
# | TimestepsSoFar          | 36864        |
# | entloss                 | 0.0          |
# | entropy                 | 6.62576      |
# | explained_variance_t... | 0.00336      |
# | meankl                  | 0.0065383087 |
# | optimgain               | 0.12084991   |
# | surrgain                | 0.12084991   |
# ------------------------------------------
# ********** Iteration 36 ************
# Optimizing Policy...
# sampling
# done in 0.423 seconds
# computegrad
# done in 0.057 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0485          0
#          1     0.0779       2.11
#          2     0.0195       3.14
#          3     0.0109       3.79
#          4    0.00402       4.39
#          5    0.00275       4.81
#          6    0.00188       5.16
#          7   0.000996       5.43
#          8   0.000404       5.65
#          9   0.000188       5.75
#         10   0.000107        5.8
# done in 0.090 seconds
# Expected: 0.138 Actual: 0.130
# Stepsize OK!
# vf
# done in 0.033 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -178        |
# | EpThisIter              | 42          |
# | EpisodesSoFar           | 1578        |
# | TimeElapsed             | 24.3        |
# | TimestepsSoFar          | 37888       |
# | entloss                 | 0.0         |
# | entropy                 | 6.6148725   |
# | explained_variance_t... | 0.00254     |
# | meankl                  | 0.006314327 |
# | optimgain               | 0.13034177  |
# | surrgain                | 0.13034177  |
# -----------------------------------------
# ********** Iteration 37 ************
# Optimizing Policy...
# sampling
# done in 0.403 seconds
# computegrad
# done in 0.056 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0492          0
#          1     0.0745        1.7
#          2     0.0249       2.83
#          3    0.00973       3.41
#          4    0.00466       4.03
#          5    0.00277       4.46
#          6     0.0017       4.76
#          7   0.000863          5
#          8   0.000486       5.19
#          9   0.000261        5.3
#         10   0.000119       5.37
# done in 0.093 seconds
# Expected: 0.132 Actual: 0.122
# Stepsize OK!
# vf
# done in 0.035 seconds
# ----------------------------------------
# | EpLenMean               | 24         |
# | EpRewMean               | -72.7      |
# | EpThisIter              | 43         |
# | EpisodesSoFar           | 1621       |
# | TimeElapsed             | 24.9       |
# | TimestepsSoFar          | 38912      |
# | entloss                 | 0.0        |
# | entropy                 | 6.6002626  |
# | explained_variance_t... | 0.00324    |
# | meankl                  | 0.00637383 |
# | optimgain               | 0.12248005 |
# | surrgain                | 0.12248005 |
# ----------------------------------------
# ********** Iteration 38 ************
# Optimizing Policy...
# sampling
# done in 0.448 seconds
# computegrad
# done in 0.057 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0491          0
#          1     0.0906       1.63
#          2     0.0208       2.83
#          3     0.0109       3.51
#          4    0.00453       4.11
#          5    0.00302       4.53
#          6    0.00201       4.84
#          7   0.000987       5.07
#          8   0.000592       5.26
#          9   0.000277       5.39
#         10   0.000137       5.46
# done in 0.099 seconds
# Expected: 0.133 Actual: 0.124
# Stepsize OK!
# vf
# done in 0.036 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | -98.1       |
# | EpThisIter              | 43          |
# | EpisodesSoFar           | 1664        |
# | TimeElapsed             | 25.6        |
# | TimestepsSoFar          | 39936       |
# | entloss                 | 0.0         |
# | entropy                 | 6.5860944   |
# | explained_variance_t... | 0.00304     |
# | meankl                  | 0.006285472 |
# | optimgain               | 0.12357958  |
# | surrgain                | 0.12357958  |
# -----------------------------------------
# ********** Iteration 39 ************
# Optimizing Policy...
# sampling
# done in 0.407 seconds
# computegrad
# done in 0.060 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0472          0
#          1     0.0652       2.15
#          2     0.0216       2.84
#          3     0.0134       3.53
#          4    0.00443       4.14
#          5    0.00236       4.57
#          6    0.00149       4.92
#          7   0.000921       5.12
#          8   0.000601       5.29
#          9   0.000359       5.39
# ...
# ********** Iteration 183 ************
# Optimizing Policy...
# sampling
# done in 0.400 seconds
# computegrad
# done in 0.051 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.189          0
#          1     0.0732     0.0617
#          2      0.152      0.484
#          3     0.0264      0.977
#          4     0.0198       1.56
#          5     0.0261       1.84
#          6      0.107       2.29
#          7     0.0156       2.45
#          8     0.0118       3.07
#          9     0.0101       3.61
#         10      0.018       3.78
# done in 0.083 seconds
# Expected: 0.104 Actual: 0.095
# Stepsize OK!
# vf
# done in 0.033 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | 441          |
# | EpThisIter              | 42           |
# | EpisodesSoFar           | 7850         |
# | TimeElapsed             | 120          |
# | TimestepsSoFar          | 188416       |
# | entloss                 | 0.0          |
# | entropy                 | 5.405454     |
# | explained_variance_t... | -0.000144    |
# | meankl                  | 0.0070515466 |
# | optimgain               | 0.09488179   |
# | surrgain                | 0.09488179   |
# ------------------------------------------
# ********** Iteration 184 ************
# Optimizing Policy...
# sampling
# done in 0.426 seconds
# computegrad
# done in 0.055 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.135          0
#          1       0.12     0.0685
#          2      0.139      0.333
#          3     0.0346      0.741
#          4     0.0309       1.12
#          5     0.0213       1.57
#          6      0.112       2.12
#          7     0.0174       2.25
#          8      0.013       2.99
#          9     0.0127       3.65
#         10     0.0292       3.85
# done in 0.084 seconds
# Expected: 0.103 Actual: 0.094
# Stepsize OK!
# vf
# done in 0.033 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | 481         |
# | EpThisIter              | 43          |
# | EpisodesSoFar           | 7893        |
# | TimeElapsed             | 121         |
# | TimestepsSoFar          | 189440      |
# | entloss                 | 0.0         |
# | entropy                 | 5.3988886   |
# | explained_variance_t... | -0.00015    |
# | meankl                  | 0.006998836 |
# | optimgain               | 0.09431034  |
# | surrgain                | 0.09431034  |
# -----------------------------------------
# ********** Iteration 185 ************
# Optimizing Policy...
# sampling
# done in 0.380 seconds
# computegrad
# done in 0.059 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0661          0
#          1       0.13     0.0743
#          2     0.0376       0.77
#          3     0.0727      0.951
#          4     0.0206       1.54
#          5     0.0193          2
#          6     0.0766       2.35
#          7     0.0256       2.46
#          8      0.015       3.09
#          9    0.00851       3.69
#         10     0.0269       4.01
# done in 0.099 seconds
# Expected: 0.102 Actual: 0.101
# Stepsize OK!
# vf
# done in 0.034 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | 469          |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 7936         |
# | TimeElapsed             | 122          |
# | TimestepsSoFar          | 190464       |
# | entloss                 | 0.0          |
# | entropy                 | 5.4060993    |
# | explained_variance_t... | -0.00015     |
# | meankl                  | 0.0078113256 |
# | optimgain               | 0.10137293   |
# | surrgain                | 0.10137293   |
# ------------------------------------------
# ********** Iteration 186 ************
# Optimizing Policy...
# sampling
# done in 0.409 seconds
# computegrad
# done in 0.054 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.102          0
#          1      0.145      0.079
#          2      0.132      0.517
#          3     0.0295      0.815
#          4     0.0242       1.26
#          5     0.0179       1.55
#          6     0.0512       2.08
#          7     0.0159       2.15
#          8     0.0108       2.86
#          9     0.0101       3.36
#         10     0.0121       3.47
# done in 0.084 seconds
# Expected: 0.099 Actual: 0.092
# Stepsize OK!
# vf
# done in 0.033 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | 471         |
# | EpThisIter              | 42          |
# | EpisodesSoFar           | 7978        |
# | TimeElapsed             | 122         |
# | TimestepsSoFar          | 191488      |
# | entloss                 | 0.0         |
# | entropy                 | 5.3972588   |
# | explained_variance_t... | -0.000145   |
# | meankl                  | 0.008052295 |
# | optimgain               | 0.091817364 |
# | surrgain                | 0.091817364 |
# -----------------------------------------
# ********** Iteration 187 ************
# Optimizing Policy...
# sampling
# done in 0.391 seconds
# computegrad
# done in 0.051 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0767          0
#          1       0.12      0.111
#          2     0.0466      0.682
#          3     0.0297       1.03
#          4      0.035       1.22
#          5     0.0128       1.51
#          6     0.0137       1.87
#          7     0.0728       2.18
#          8     0.0116       2.42
#          9    0.00657       3.11
#         10     0.0045       3.54
# done in 0.083 seconds
# Expected: 0.095 Actual: 0.089
# Stepsize OK!
# vf
# done in 0.034 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | 489          |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 8021         |
# | TimeElapsed             | 123          |
# | TimestepsSoFar          | 192512       |
# | entloss                 | 0.0          |
# | entropy                 | 5.388815     |
# | explained_variance_t... | -0.000141    |
# | meankl                  | 0.0068867896 |
# | optimgain               | 0.08935803   |
# | surrgain                | 0.08935803   |
# ------------------------------------------
# ********** Iteration 188 ************
# Optimizing Policy...
# sampling
# done in 0.362 seconds
# computegrad
# done in 0.052 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0691          0
#          1      0.222      0.216
#          2     0.0372      0.687
#          3     0.0459       0.94
#          4     0.0386       1.24
#          5     0.0151       1.62
#          6     0.0154       2.24
#          7      0.112       2.64
#          8     0.0124       3.06
#          9    0.00715       3.64
#         10    0.00495       4.04
# done in 0.083 seconds
# Expected: 0.102 Actual: 0.095
# Stepsize OK!
# vf
# done in 0.032 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | 470          |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 8064         |
# | TimeElapsed             | 123          |
# | TimestepsSoFar          | 193536       |
# | entloss                 | 0.0          |
# | entropy                 | 5.3529882    |
# | explained_variance_t... | -0.00013     |
# | meankl                  | 0.0068542855 |
# | optimgain               | 0.09540066   |
# | surrgain                | 0.09540066   |
# ------------------------------------------
# ********** Iteration 189 ************
# Optimizing Policy...
# sampling
# done in 0.387 seconds
# computegrad
# done in 0.058 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0609          0
#          1      0.311      0.381
#          2     0.0467      0.733
#          3     0.0516      0.937
#          4     0.0241       1.33
#          5     0.0211       1.66
#          6     0.0165       2.08
#          7       0.12       2.42
#          8      0.014       2.82
#          9       0.01       3.51
#         10    0.00731       4.03
# done in 0.094 seconds
# Expected: 0.103 Actual: 0.095
# Stepsize OK!
# vf
# done in 0.033 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | 477          |
# | EpThisIter              | 42           |
# | EpisodesSoFar           | 8106         |
# | TimeElapsed             | 124          |
# | TimestepsSoFar          | 194560       |
# | entloss                 | 0.0          |
# | entropy                 | 5.348236     |
# | explained_variance_t... | -0.000126    |
# | meankl                  | 0.0068231802 |
# | optimgain               | 0.094782904  |
# | surrgain                | 0.094782904  |
# ------------------------------------------
# ********** Iteration 190 ************
# Optimizing Policy...
# sampling
# done in 0.397 seconds
# computegrad
# done in 0.051 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0788          0
#          1      0.183      0.108
#          2     0.0364      0.768
#          3     0.0235       1.31
#          4      0.051       1.58
#          5     0.0202       1.86
#          6     0.0227       2.26
#          7     0.0672        2.7
#          8     0.0145       2.82
#          9     0.0089        3.4
#         10    0.00644       3.82
# done in 0.084 seconds
# Expected: 0.104 Actual: 0.098
# Stepsize OK!
# vf
# done in 0.033 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | 482          |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 8149         |
# | TimeElapsed             | 125          |
# | TimestepsSoFar          | 195584       |
# | entloss                 | 0.0          |
# | entropy                 | 5.352005     |
# | explained_variance_t... | -0.000131    |
# | meankl                  | 0.0071200784 |
# | optimgain               | 0.09796511   |
# | surrgain                | 0.09796511   |
# ------------------------------------------
# ********** Iteration 191 ************
# Optimizing Policy...
# sampling
# done in 0.416 seconds
# computegrad
# done in 0.053 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0609          0
#          1      0.154      0.171
#          2      0.108      0.556
#          3     0.0295      0.919
#          4     0.0175       1.32
#          5     0.0196       1.66
#          6     0.0225       2.03
#          7     0.0545       2.55
#          8     0.0156        2.7
#          9    0.00917       3.29
#         10    0.00619       3.69
# done in 0.086 seconds
# Expected: 0.097 Actual: 0.092
# Stepsize OK!
# vf
# done in 0.035 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | 474          |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 8192         |
# | TimeElapsed             | 125          |
# | TimestepsSoFar          | 196608       |
# | entloss                 | 0.0          |
# | entropy                 | 5.346829     |
# | explained_variance_t... | -0.000127    |
# | meankl                  | 0.0070766285 |
# | optimgain               | 0.09178558   |
# | surrgain                | 0.09178558   |
# ------------------------------------------
# ********** Iteration 192 ************
# Optimizing Policy...
# sampling
# done in 0.412 seconds
# computegrad
# done in 0.059 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0548          0
#          1      0.161      0.348
#          2     0.0425      0.605
#          3     0.0339      0.924
#          4     0.0347        1.2
#          5     0.0128       1.45
#          6     0.0135       1.88
#          7     0.0143       2.47
#          8     0.0286       2.59
#          9    0.00825       3.05
#         10    0.00502       3.51
# done in 0.097 seconds
# Expected: 0.093 Actual: 0.090
# Stepsize OK!
# vf
# done in 0.032 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | 486         |
# | EpThisIter              | 42          |
# | EpisodesSoFar           | 8234        |
# | TimeElapsed             | 126         |
# | TimestepsSoFar          | 197632      |
# | entloss                 | 0.0         |
# | entropy                 | 5.351139    |
# | explained_variance_t... | -0.000129   |
# | meankl                  | 0.007234153 |
# | optimgain               | 0.090319626 |
# | surrgain                | 0.090319626 |
# -----------------------------------------
# ********** Iteration 193 ************
# Optimizing Policy...
# sampling
# done in 0.399 seconds
# computegrad
# done in 0.052 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0591          0
#          1      0.131      0.136
#          2     0.0313      0.777
#          3     0.0505       1.06
#          4     0.0179        1.3
#          5      0.016       1.59
#          6     0.0141       2.06
#          7     0.0365       2.54
#          8     0.0148       2.66
#          9    0.00881       3.15
#         10    0.00594        3.6
# done in 0.084 seconds
# Expected: 0.094 Actual: 0.091
# Stepsize OK!
# vf
# done in 0.034 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | 484          |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 8277         |
# | TimeElapsed             | 127          |
# | TimestepsSoFar          | 198656       |
# | entloss                 | 0.0          |
# | entropy                 | 5.341666     |
# | explained_variance_t... | -0.000123    |
# | meankl                  | 0.0070167114 |
# | optimgain               | 0.091142446  |
# | surrgain                | 0.091142446  |
# ------------------------------------------
# ********** Iteration 194 ************
# Optimizing Policy...
# sampling
# done in 0.418 seconds
# computegrad
# done in 0.052 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0746          0
#          1      0.234      0.324
#          2     0.0528      0.605
#          3     0.0861      0.926
#          4     0.0263       1.19
#          5     0.0135       1.56
#          6     0.0151       1.99
#          7      0.026       2.53
#          8     0.0303       2.65
#          9     0.0157       3.08
#         10    0.00883       3.65
# done in 0.083 seconds
# Expected: 0.101 Actual: 0.092
# Stepsize OK!
# vf
# done in 0.034 seconds
# ------------------------------------------
# | EpLenMean               | 24           |
# | EpRewMean               | 465          |
# | EpThisIter              | 43           |
# | EpisodesSoFar           | 8320         |
# | TimeElapsed             | 127          |
# | TimestepsSoFar          | 199680       |
# | entloss                 | 0.0          |
# | entropy                 | 5.3378077    |
# | explained_variance_t... | -0.000121    |
# | meankl                  | 0.0076619983 |
# | optimgain               | 0.09205361   |
# | surrgain                | 0.09205361   |
# ------------------------------------------
# ********** Iteration 195 ************
# Optimizing Policy...
# sampling
# done in 0.417 seconds
# computegrad
# done in 0.055 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0547          0
#          1      0.122      0.184
#          2     0.0911      0.507
#          3     0.0293      0.786
#          4     0.0168       1.18
#          5    0.00913       1.52
#          6     0.0117          2
#          7     0.0398       2.44
#          8     0.0126       2.59
#          9    0.00784       2.94
#         10    0.00546       3.29
# done in 0.086 seconds
# Expected: 0.088 Actual: 0.088
# Stepsize OK!
# vf
# done in 0.031 seconds
# -----------------------------------------
# | EpLenMean               | 24          |
# | EpRewMean               | 464         |
# | EpThisIter              | 42          |
# | EpisodesSoFar           | 8362        |
# | TimeElapsed             | 128         |
# | TimestepsSoFar          | 200704      |
# | entloss                 | 0.0         |
# | entropy                 | 5.3326693   |
# | explained_variance_t... | -0.000125   |
# | meankl                  | 0.007350841 |
# | optimgain               | 0.087538674 |
# | surrgain                | 0.087538674 |
# -----------------------------------------

# %%
results_plotter.plot_results([log_dir], time_steps, results_plotter.X_TIMESTEPS, "TRPO")
plt.show()

# %%
obs = env.reset()
for i in range(199):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()

# %% [markdown]
# # DDPG

# %%
from stable_baselines.ddpg.policies import MlpPolicy

# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

env = gym.make('ElectricityMarket-v0')
env = Monitor(env, log_dir, allow_early_resets=True)
env = DummyVecEnv(([lambda: env]))

# The noise objects for TD3
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

model = DDPG(MlpPolicy, env, action_noise=action_noise, verbose=1)

# Train the agent
time_steps = 80000
model.learn(total_timesteps=time_steps)

# %%
results_plotter.plot_results([log_dir], time_steps, results_plotter.X_TIMESTEPS, "DDPG")
plt.show()

# %% [markdown]
# # Q-learning

# %%
from stable_baselines.deepq.policies import MlpPolicy

# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

env = gym.make('ElectricityMarketDiscreteDQN-v0')
env = Monitor(env, log_dir, allow_early_resets=True)
env = DummyVecEnv(([lambda: env]))

model = DQN(MlpPolicy, env, verbose=1)

# Train the agent
time_steps = 300000
model.learn(total_timesteps=time_steps)

# %%
results_plotter.plot_results([log_dir], time_steps, results_plotter.X_TIMESTEPS, "Q-learning")
plt.show()

# %% [markdown]
# # A2C

# %%
from stable_baselines.common.policies import MlpPolicy

# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

env = gym.make('ElectricityMarket-v0')
env = Monitor(env, log_dir, allow_early_resets=True)
env = DummyVecEnv(([lambda: env]))

model = A2C(MlpPolicy, env, verbose=1)

# Train the agent
time_steps = 20000
model.learn(total_timesteps=time_steps)

# %%
results_plotter.plot_results([log_dir], time_steps, results_plotter.X_TIMESTEPS, "A2C")
plt.show()
